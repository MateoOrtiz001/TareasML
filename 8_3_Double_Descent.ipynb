# %% [markdown]
# <a href="https://colab.research.google.com/github/MateoOrtiz001/TareasML/blob/main/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to make a local copy of the MNIST 1D repository
# !git clone https://github.com/greydanus/mnist1d
# Out:
# Cloning into 'mnist1d'...
# remote: Enumerating objects: 204, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 204 (delta 47), reused 60 (delta 41), pack-reused 128
# Receiving objects: 100% (204/204), 8.42 MiB | 23.25 MiB/s, done.
# Resolving deltas: 100% (73/73), done.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  # loop over the dataset n_epoch times
  n_epoch = 1000

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %% [markdown]
# ANS:
# 1. Cuando el número de hiper parámetros sea igual al número de neuronas del input.
# 2. Cuando el número de hiper parámetros sea el máximo (400)
# 3. Cuando el número de hiper parámetros es el mínimo (2) o en el mismo instante de 1.

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Train the model
    errors_train, errors_test = fit_model(model, data)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.293691, train error 88.95,  test loss 2.296664, test error 89.82
# Epoch   100, train loss 1.914541, train error 71.80,  test loss 1.762845, test error 71.32
# Epoch   200, train loss 1.889215, train error 70.88,  test loss 1.732536, test error 68.60
# Epoch   300, train loss 1.883780, train error 70.97,  test loss 1.717039, test error 67.57
# Epoch   400, train loss 1.878711, train error 69.57,  test loss 1.726220, test error 68.00
# Epoch   500, train loss 1.878912, train error 70.53,  test loss 1.712242, test error 68.22
# Epoch   600, train loss 1.877111, train error 69.97,  test loss 1.725069, test error 68.10
# Epoch   700, train loss 1.887309, train error 71.82,  test loss 1.744383, test error 69.78
# Epoch   800, train loss 1.878683, train error 70.35,  test loss 1.731239, test error 69.85
# Epoch   900, train loss 1.876278, train error 71.05,  test loss 1.722741, test error 67.20
# Training model with   4 hidden variables
# Epoch     0, train loss 2.266054, train error 88.45,  test loss 2.263613, test error 87.65
# Epoch   100, train loss 1.784805, train error 64.78,  test loss 1.592997, test error 62.03
# Epoch   200, train loss 1.782827, train error 65.80,  test loss 1.581479, test error 61.70
# Epoch   300, train loss 1.756857, train error 64.62,  test loss 1.553093, test error 60.88
# Epoch   400, train loss 1.760972, train error 65.00,  test loss 1.567635, test error 60.92
# Epoch   500, train loss 1.761033, train error 64.82,  test loss 1.568054, test error 60.83
# Epoch   600, train loss 1.750270, train error 64.12,  test loss 1.553836, test error 60.70
# Epoch   700, train loss 1.750435, train error 64.15,  test loss 1.555665, test error 61.25
# Epoch   800, train loss 1.753682, train error 64.68,  test loss 1.570023, test error 61.38
# Epoch   900, train loss 1.753105, train error 63.97,  test loss 1.556807, test error 60.90
# Training model with   6 hidden variables
# Epoch     0, train loss 2.197437, train error 81.22,  test loss 2.160665, test error 80.07
# Epoch   100, train loss 1.649436, train error 57.22,  test loss 1.477153, test error 55.72
# Epoch   200, train loss 1.601464, train error 55.33,  test loss 1.410431, test error 52.25
# Epoch   300, train loss 1.582996, train error 54.25,  test loss 1.396778, test error 51.78
# Epoch   400, train loss 1.570855, train error 54.10,  test loss 1.381822, test error 51.30
# Epoch   500, train loss 1.576783, train error 54.55,  test loss 1.410887, test error 52.40
# Epoch   600, train loss 1.564583, train error 53.83,  test loss 1.390029, test error 51.22
# Epoch   700, train loss 1.576489, train error 54.45,  test loss 1.397573, test error 52.12
# Epoch   800, train loss 1.560889, train error 54.22,  test loss 1.382620, test error 51.53
# Epoch   900, train loss 1.555615, train error 53.62,  test loss 1.385235, test error 50.70
# Training model with   8 hidden variables
# Epoch     0, train loss 2.260443, train error 85.43,  test loss 2.252578, test error 84.93
# Epoch   100, train loss 1.598024, train error 55.60,  test loss 1.428547, test error 54.62
# Epoch   200, train loss 1.555849, train error 54.67,  test loss 1.397517, test error 53.35
# Epoch   300, train loss 1.531103, train error 53.47,  test loss 1.393378, test error 53.38
# Epoch   400, train loss 1.509962, train error 52.55,  test loss 1.383613, test error 51.78
# Epoch   500, train loss 1.501944, train error 52.15,  test loss 1.385300, test error 51.47
# Epoch   600, train loss 1.498357, train error 51.53,  test loss 1.377327, test error 51.25
# Epoch   700, train loss 1.489398, train error 51.08,  test loss 1.382385, test error 50.97
# Epoch   800, train loss 1.484961, train error 50.78,  test loss 1.369291, test error 50.28
# Epoch   900, train loss 1.470913, train error 49.95,  test loss 1.351770, test error 49.62
# Training model with  10 hidden variables
# Epoch     0, train loss 2.257480, train error 85.38,  test loss 2.248472, test error 85.68
# Epoch   100, train loss 1.522816, train error 50.75,  test loss 1.341192, test error 49.67
# Epoch   200, train loss 1.471778, train error 49.08,  test loss 1.317874, test error 48.88
# Epoch   300, train loss 1.448375, train error 47.97,  test loss 1.330786, test error 48.47
# Epoch   400, train loss 1.434409, train error 48.15,  test loss 1.340714, test error 48.62
# Epoch   500, train loss 1.423512, train error 47.33,  test loss 1.339459, test error 49.20
# Epoch   600, train loss 1.421937, train error 47.33,  test loss 1.359535, test error 49.22
# Epoch   700, train loss 1.413652, train error 47.42,  test loss 1.356001, test error 48.78
# Epoch   800, train loss 1.413852, train error 46.95,  test loss 1.358074, test error 49.38
# Epoch   900, train loss 1.409810, train error 47.17,  test loss 1.361247, test error 48.50
# Training model with  14 hidden variables
# Epoch     0, train loss 2.230590, train error 83.18,  test loss 2.204708, test error 82.28
# Epoch   100, train loss 1.420478, train error 47.72,  test loss 1.334893, test error 49.33
# Epoch   200, train loss 1.353170, train error 45.95,  test loss 1.363304, test error 50.40
# Epoch   300, train loss 1.324455, train error 44.83,  test loss 1.381953, test error 50.65
# Epoch   400, train loss 1.312655, train error 44.78,  test loss 1.391678, test error 50.72
# Epoch   500, train loss 1.304620, train error 44.22,  test loss 1.397139, test error 51.05
# Epoch   600, train loss 1.297482, train error 44.03,  test loss 1.405403, test error 51.53
# Epoch   700, train loss 1.305828, train error 44.38,  test loss 1.418790, test error 51.20
# Epoch   800, train loss 1.293732, train error 44.00,  test loss 1.411465, test error 51.20
# Epoch   900, train loss 1.291283, train error 44.10,  test loss 1.414839, test error 51.78
# Training model with  18 hidden variables
# Epoch     0, train loss 2.223186, train error 81.70,  test loss 2.195974, test error 80.15
# Epoch   100, train loss 1.334484, train error 43.42,  test loss 1.282799, test error 47.12
# Epoch   200, train loss 1.247749, train error 40.85,  test loss 1.313457, test error 48.62
# Epoch   300, train loss 1.215272, train error 40.00,  test loss 1.348005, test error 48.33
# Epoch   400, train loss 1.195697, train error 38.95,  test loss 1.377861, test error 48.97
# Epoch   500, train loss 1.174828, train error 38.47,  test loss 1.404496, test error 48.88
# Epoch   600, train loss 1.168518, train error 39.03,  test loss 1.411626, test error 50.05
# Epoch   700, train loss 1.161256, train error 37.53,  test loss 1.434419, test error 49.78
# Epoch   800, train loss 1.153738, train error 38.25,  test loss 1.458889, test error 50.15
# Epoch   900, train loss 1.152115, train error 38.12,  test loss 1.466239, test error 50.05
# Training model with  22 hidden variables
# Epoch     0, train loss 2.170829, train error 81.75,  test loss 2.119997, test error 80.97
# Epoch   100, train loss 1.329767, train error 44.53,  test loss 1.360561, test error 51.88
# Epoch   200, train loss 1.183095, train error 39.70,  test loss 1.424413, test error 51.78
# Epoch   300, train loss 1.120994, train error 38.00,  test loss 1.529023, test error 53.78
# Epoch   400, train loss 1.091780, train error 37.42,  test loss 1.590926, test error 54.60
# Epoch   500, train loss 1.075952, train error 37.35,  test loss 1.622036, test error 54.55
# Epoch   600, train loss 1.060777, train error 37.17,  test loss 1.708888, test error 54.80
# Epoch   700, train loss 1.053720, train error 36.65,  test loss 1.757890, test error 54.90
# Epoch   800, train loss 1.044361, train error 36.58,  test loss 1.804442, test error 55.42
# Epoch   900, train loss 1.032302, train error 36.25,  test loss 1.873975, test error 56.20
# Training model with  26 hidden variables
# Epoch     0, train loss 2.196206, train error 80.85,  test loss 2.187482, test error 81.22
# Epoch   100, train loss 1.226610, train error 39.28,  test loss 1.341950, test error 49.92
# Epoch   200, train loss 1.070876, train error 35.32,  test loss 1.435928, test error 49.58
# Epoch   300, train loss 1.012180, train error 32.65,  test loss 1.544111, test error 50.53
# Epoch   400, train loss 0.954208, train error 31.95,  test loss 1.698206, test error 51.70
# Epoch   500, train loss 0.909041, train error 30.65,  test loss 1.821072, test error 52.42
# Epoch   600, train loss 0.876145, train error 29.80,  test loss 1.914832, test error 52.42
# Epoch   700, train loss 0.869145, train error 29.18,  test loss 2.006111, test error 52.15
# Epoch   800, train loss 0.855531, train error 29.45,  test loss 2.092644, test error 52.88
# Epoch   900, train loss 0.847858, train error 28.72,  test loss 2.136045, test error 53.55
# Training model with  30 hidden variables
# Epoch     0, train loss 2.150429, train error 80.82,  test loss 2.073015, test error 79.43
# Epoch   100, train loss 1.135309, train error 37.58,  test loss 1.336996, test error 47.83
# Epoch   200, train loss 0.964402, train error 31.38,  test loss 1.519049, test error 50.35
# Epoch   300, train loss 0.881033, train error 29.43,  test loss 1.689541, test error 52.22
# Epoch   400, train loss 0.827212, train error 27.15,  test loss 1.845080, test error 52.75
# Epoch   500, train loss 0.783119, train error 26.03,  test loss 2.019936, test error 53.10
# Epoch   600, train loss 0.758261, train error 25.97,  test loss 2.167291, test error 53.42
# Epoch   700, train loss 0.724446, train error 24.68,  test loss 2.280221, test error 53.80
# Epoch   800, train loss 0.715220, train error 24.43,  test loss 2.438211, test error 54.97
# Epoch   900, train loss 0.717350, train error 24.47,  test loss 2.555471, test error 55.62
# Training model with  35 hidden variables
# Epoch     0, train loss 2.170784, train error 79.32,  test loss 2.134794, test error 78.75
# Epoch   100, train loss 1.031412, train error 33.40,  test loss 1.394758, test error 48.83
# Epoch   200, train loss 0.829571, train error 27.80,  test loss 1.648228, test error 50.62
# Epoch   300, train loss 0.705444, train error 24.25,  test loss 1.943506, test error 52.50
# Epoch   400, train loss 0.613154, train error 20.55,  test loss 2.291106, test error 54.55
# Epoch   500, train loss 0.582376, train error 20.25,  test loss 2.608333, test error 55.33
# Epoch   600, train loss 0.544504, train error 19.78,  test loss 2.881317, test error 55.05
# Epoch   700, train loss 0.518433, train error 18.35,  test loss 3.083490, test error 55.03
# Epoch   800, train loss 0.501189, train error 17.70,  test loss 3.312598, test error 55.88
# Epoch   900, train loss 0.490976, train error 17.62,  test loss 3.623348, test error 56.78
# Training model with  40 hidden variables
# Epoch     0, train loss 2.131263, train error 78.45,  test loss 2.092111, test error 78.10
# Epoch   100, train loss 0.941621, train error 29.68,  test loss 1.409841, test error 50.22
# Epoch   200, train loss 0.656333, train error 20.88,  test loss 1.945375, test error 53.45
# Epoch   300, train loss 0.500322, train error 15.53,  test loss 2.541011, test error 54.47
# Epoch   400, train loss 0.402611, train error 12.40,  test loss 3.321275, test error 56.08
# Epoch   500, train loss 0.337895, train error 11.15,  test loss 4.085780, test error 56.42
# Epoch   600, train loss 0.319750, train error 11.18,  test loss 4.808139, test error 55.88
# Epoch   700, train loss 0.347270, train error 12.30,  test loss 5.615455, test error 58.20
# Epoch   800, train loss 0.326235, train error 11.38,  test loss 6.191581, test error 57.33
# Epoch   900, train loss 0.257865, train error 8.47,  test loss 6.957859, test error 57.08
# Training model with  45 hidden variables
# Epoch     0, train loss 2.094044, train error 78.12,  test loss 2.061598, test error 78.75
# Epoch   100, train loss 0.836258, train error 26.80,  test loss 1.587679, test error 51.62
# Epoch   200, train loss 0.515571, train error 15.82,  test loss 2.299510, test error 54.12
# Epoch   300, train loss 0.378707, train error 12.43,  test loss 3.284297, test error 56.40
# Epoch   400, train loss 0.252069, train error 8.43,  test loss 4.509736, test error 57.45
# Epoch   500, train loss 0.140141, train error 3.95,  test loss 5.711266, test error 57.60
# Epoch   600, train loss 0.157711, train error 5.20,  test loss 6.902985, test error 58.00
# Epoch   700, train loss 0.256600, train error 8.95,  test loss 7.855819, test error 56.78
# Epoch   800, train loss 0.010913, train error 0.03,  test loss 8.826183, test error 57.38
# Epoch   900, train loss 0.007010, train error 0.00,  test loss 9.496056, test error 57.75
# Training model with  50 hidden variables
# Epoch     0, train loss 2.109692, train error 78.45,  test loss 2.052981, test error 78.00
# Epoch   100, train loss 0.711645, train error 21.72,  test loss 1.633894, test error 51.78
# Epoch   200, train loss 0.319633, train error 9.30,  test loss 2.725837, test error 54.40
# Epoch   300, train loss 0.142717, train error 3.07,  test loss 4.404018, test error 56.88
# Epoch   400, train loss 0.026188, train error 0.00,  test loss 5.953504, test error 56.35
# Epoch   500, train loss 0.013123, train error 0.00,  test loss 6.918545, test error 56.50
# Epoch   600, train loss 0.008195, train error 0.00,  test loss 7.550344, test error 56.67
# Epoch   700, train loss 0.005946, train error 0.00,  test loss 8.032801, test error 56.38
# Epoch   800, train loss 0.004557, train error 0.00,  test loss 8.415359, test error 56.50
# Epoch   900, train loss 0.003676, train error 0.00,  test loss 8.732806, test error 56.53
# Training model with  55 hidden variables
# Epoch     0, train loss 2.102505, train error 77.03,  test loss 2.065490, test error 76.93
# Epoch   100, train loss 0.607995, train error 18.75,  test loss 1.660464, test error 50.38
# Epoch   200, train loss 0.199925, train error 4.35,  test loss 3.108122, test error 54.08
# Epoch   300, train loss 0.038708, train error 0.05,  test loss 4.814258, test error 55.30
# Epoch   400, train loss 0.013236, train error 0.00,  test loss 5.842772, test error 55.58
# Epoch   500, train loss 0.007777, train error 0.00,  test loss 6.474013, test error 56.12
# Epoch   600, train loss 0.005444, train error 0.00,  test loss 6.922090, test error 56.17
# Epoch   700, train loss 0.004052, train error 0.00,  test loss 7.273358, test error 56.10
# Epoch   800, train loss 0.003222, train error 0.00,  test loss 7.559339, test error 56.10
# Epoch   900, train loss 0.002648, train error 0.00,  test loss 7.803385, test error 56.22
# Training model with  60 hidden variables
# Epoch     0, train loss 2.088118, train error 77.47,  test loss 2.048784, test error 77.07
# Epoch   100, train loss 0.540037, train error 16.30,  test loss 1.890175, test error 53.72
# Epoch   200, train loss 0.104448, train error 1.20,  test loss 3.679159, test error 55.72
# Epoch   300, train loss 0.019489, train error 0.00,  test loss 5.184952, test error 56.20
# Epoch   400, train loss 0.009389, train error 0.00,  test loss 5.923204, test error 56.10
# Epoch   500, train loss 0.005951, train error 0.00,  test loss 6.407503, test error 56.25
# Epoch   600, train loss 0.004307, train error 0.00,  test loss 6.776462, test error 56.22
# Epoch   700, train loss 0.003292, train error 0.00,  test loss 7.064730, test error 56.55
# Epoch   800, train loss 0.002644, train error 0.00,  test loss 7.303486, test error 56.40
# Epoch   900, train loss 0.002204, train error 0.00,  test loss 7.506936, test error 56.35
# Training model with  70 hidden variables
# Epoch     0, train loss 2.031662, train error 74.97,  test loss 1.961271, test error 74.43
# Epoch   100, train loss 0.414205, train error 11.32,  test loss 1.847858, test error 50.38
# Epoch   200, train loss 0.037392, train error 0.00,  test loss 3.491406, test error 53.55
# Epoch   300, train loss 0.011582, train error 0.00,  test loss 4.308640, test error 53.85
# Epoch   400, train loss 0.006347, train error 0.00,  test loss 4.764033, test error 53.78
# Epoch   500, train loss 0.004233, train error 0.00,  test loss 5.068841, test error 53.60
# Epoch   600, train loss 0.003115, train error 0.00,  test loss 5.311626, test error 53.53
# Epoch   700, train loss 0.002445, train error 0.00,  test loss 5.502474, test error 53.47
# Epoch   800, train loss 0.001991, train error 0.00,  test loss 5.660683, test error 53.53
# Epoch   900, train loss 0.001675, train error 0.00,  test loss 5.797529, test error 53.47
# Training model with  80 hidden variables
# Epoch     0, train loss 2.014871, train error 75.25,  test loss 1.950748, test error 75.12
# Epoch   100, train loss 0.234248, train error 4.38,  test loss 2.167579, test error 52.42
# Epoch   200, train loss 0.018750, train error 0.00,  test loss 3.541745, test error 52.38
# Epoch   300, train loss 0.007630, train error 0.00,  test loss 4.106200, test error 52.75
# Epoch   400, train loss 0.004494, train error 0.00,  test loss 4.439519, test error 52.78
# Epoch   500, train loss 0.003125, train error 0.00,  test loss 4.680806, test error 52.58
# Epoch   600, train loss 0.002355, train error 0.00,  test loss 4.865785, test error 52.78
# Epoch   700, train loss 0.001874, train error 0.00,  test loss 5.019958, test error 52.85
# Epoch   800, train loss 0.001545, train error 0.00,  test loss 5.144045, test error 52.92
# Epoch   900, train loss 0.001308, train error 0.00,  test loss 5.254721, test error 52.92
# Training model with  90 hidden variables
# Epoch     0, train loss 2.015127, train error 73.28,  test loss 1.951386, test error 74.45
# Epoch   100, train loss 0.157027, train error 1.45,  test loss 2.169581, test error 51.72
# Epoch   200, train loss 0.015340, train error 0.00,  test loss 3.306476, test error 51.95
# Epoch   300, train loss 0.006661, train error 0.00,  test loss 3.762572, test error 52.03
# Epoch   400, train loss 0.004028, train error 0.00,  test loss 4.033535, test error 52.17
# Epoch   500, train loss 0.002828, train error 0.00,  test loss 4.234958, test error 52.33
# Epoch   600, train loss 0.002151, train error 0.00,  test loss 4.391181, test error 52.50
# Epoch   700, train loss 0.001718, train error 0.00,  test loss 4.517307, test error 52.30
# Epoch   800, train loss 0.001421, train error 0.00,  test loss 4.625078, test error 52.35
# Epoch   900, train loss 0.001206, train error 0.00,  test loss 4.718394, test error 52.42
# Training model with 100 hidden variables
# Epoch     0, train loss 2.055090, train error 76.03,  test loss 2.013286, test error 76.78
# Epoch   100, train loss 0.098466, train error 0.25,  test loss 2.258689, test error 51.67
# Epoch   200, train loss 0.012423, train error 0.00,  test loss 3.139435, test error 51.75
# Epoch   300, train loss 0.005705, train error 0.00,  test loss 3.512321, test error 51.78
# Epoch   400, train loss 0.003555, train error 0.00,  test loss 3.745120, test error 51.78
# Epoch   500, train loss 0.002520, train error 0.00,  test loss 3.911475, test error 51.95
# Epoch   600, train loss 0.001928, train error 0.00,  test loss 4.043548, test error 51.88
# Epoch   700, train loss 0.001549, train error 0.00,  test loss 4.151598, test error 51.95
# Epoch   800, train loss 0.001286, train error 0.00,  test loss 4.243632, test error 51.90
# Epoch   900, train loss 0.001095, train error 0.00,  test loss 4.322336, test error 51.88
# Training model with 120 hidden variables
# Epoch     0, train loss 1.976127, train error 73.07,  test loss 1.911329, test error 74.05
# Epoch   100, train loss 0.046781, train error 0.00,  test loss 2.280155, test error 51.00
# Epoch   200, train loss 0.009261, train error 0.00,  test loss 2.901478, test error 50.33
# Epoch   300, train loss 0.004596, train error 0.00,  test loss 3.175457, test error 50.28
# Epoch   400, train loss 0.002956, train error 0.00,  test loss 3.357834, test error 50.28
# Epoch   500, train loss 0.002138, train error 0.00,  test loss 3.489695, test error 50.15
# Epoch   600, train loss 0.001654, train error 0.00,  test loss 3.596707, test error 50.33
# Epoch   700, train loss 0.001339, train error 0.00,  test loss 3.684275, test error 50.53
# Epoch   800, train loss 0.001119, train error 0.00,  test loss 3.758480, test error 50.40
# Epoch   900, train loss 0.000957, train error 0.00,  test loss 3.823413, test error 50.42
# Training model with 140 hidden variables
# Epoch     0, train loss 1.959671, train error 71.43,  test loss 1.894609, test error 72.82
# Epoch   100, train loss 0.035280, train error 0.00,  test loss 2.255718, test error 50.30
# Epoch   200, train loss 0.008064, train error 0.00,  test loss 2.760632, test error 50.15
# Epoch   300, train loss 0.004157, train error 0.00,  test loss 2.999496, test error 50.03
# Epoch   400, train loss 0.002708, train error 0.00,  test loss 3.158457, test error 50.03
# Epoch   500, train loss 0.001973, train error 0.00,  test loss 3.274229, test error 50.08
# Epoch   600, train loss 0.001537, train error 0.00,  test loss 3.368215, test error 50.22
# Epoch   700, train loss 0.001249, train error 0.00,  test loss 3.445338, test error 50.28
# Epoch   800, train loss 0.001046, train error 0.00,  test loss 3.511810, test error 50.22
# Epoch   900, train loss 0.000897, train error 0.00,  test loss 3.569271, test error 50.17
# Training model with 160 hidden variables
# Epoch     0, train loss 1.937776, train error 69.50,  test loss 1.862083, test error 71.38
# Epoch   100, train loss 0.027419, train error 0.00,  test loss 2.161293, test error 49.15
# Epoch   200, train loss 0.007047, train error 0.00,  test loss 2.576916, test error 49.33
# Epoch   300, train loss 0.003706, train error 0.00,  test loss 2.776198, test error 49.28
# Epoch   400, train loss 0.002442, train error 0.00,  test loss 2.911526, test error 49.35
# Epoch   500, train loss 0.001790, train error 0.00,  test loss 3.012617, test error 49.22
# Epoch   600, train loss 0.001399, train error 0.00,  test loss 3.093766, test error 49.15
# Epoch   700, train loss 0.001140, train error 0.00,  test loss 3.160932, test error 49.15
# Epoch   800, train loss 0.000957, train error 0.00,  test loss 3.218571, test error 49.17
# Epoch   900, train loss 0.000822, train error 0.00,  test loss 3.269233, test error 49.10
# Training model with 180 hidden variables
# Epoch     0, train loss 1.967442, train error 71.50,  test loss 1.872944, test error 72.70
# Epoch   100, train loss 0.024148, train error 0.00,  test loss 2.019717, test error 49.08
# Epoch   200, train loss 0.006567, train error 0.00,  test loss 2.353787, test error 48.85
# Epoch   300, train loss 0.003527, train error 0.00,  test loss 2.522586, test error 48.35
# Epoch   400, train loss 0.002336, train error 0.00,  test loss 2.638556, test error 48.17
# Epoch   500, train loss 0.001719, train error 0.00,  test loss 2.725958, test error 48.15
# Epoch   600, train loss 0.001346, train error 0.00,  test loss 2.796010, test error 48.22
# Epoch   700, train loss 0.001099, train error 0.00,  test loss 2.854166, test error 48.38
# Epoch   800, train loss 0.000925, train error 0.00,  test loss 2.903377, test error 48.30
# Epoch   900, train loss 0.000795, train error 0.00,  test loss 2.946942, test error 48.35
# Training model with 200 hidden variables
# Epoch     0, train loss 1.917130, train error 69.90,  test loss 1.828447, test error 71.00
# Epoch   100, train loss 0.021179, train error 0.00,  test loss 2.026167, test error 48.83
# Epoch   200, train loss 0.006115, train error 0.00,  test loss 2.346004, test error 48.85
# Epoch   300, train loss 0.003307, train error 0.00,  test loss 2.501505, test error 48.55
# Epoch   400, train loss 0.002207, train error 0.00,  test loss 2.611624, test error 48.30
# Epoch   500, train loss 0.001632, train error 0.00,  test loss 2.692984, test error 48.17
# Epoch   600, train loss 0.001283, train error 0.00,  test loss 2.758598, test error 48.22
# Epoch   700, train loss 0.001050, train error 0.00,  test loss 2.813064, test error 48.17
# Epoch   800, train loss 0.000884, train error 0.00,  test loss 2.860459, test error 48.15
# Epoch   900, train loss 0.000761, train error 0.00,  test loss 2.901802, test error 48.17
# Training model with 250 hidden variables
# Epoch     0, train loss 1.894913, train error 68.53,  test loss 1.794732, test error 69.88
# Epoch   100, train loss 0.016910, train error 0.00,  test loss 1.951254, test error 47.58
# Epoch   200, train loss 0.005292, train error 0.00,  test loss 2.216620, test error 47.15
# Epoch   300, train loss 0.002951, train error 0.00,  test loss 2.358312, test error 47.05
# Epoch   400, train loss 0.001991, train error 0.00,  test loss 2.454021, test error 47.20
# Epoch   500, train loss 0.001483, train error 0.00,  test loss 2.527801, test error 47.10
# Epoch   600, train loss 0.001171, train error 0.00,  test loss 2.586680, test error 47.25
# Epoch   700, train loss 0.000961, train error 0.00,  test loss 2.636286, test error 47.15
# Epoch   800, train loss 0.000812, train error 0.00,  test loss 2.678874, test error 47.08
# Epoch   900, train loss 0.000700, train error 0.00,  test loss 2.715994, test error 47.08
# Training model with 300 hidden variables
# Epoch     0, train loss 1.863771, train error 67.22,  test loss 1.777391, test error 68.65
# Epoch   100, train loss 0.014252, train error 0.00,  test loss 1.879902, test error 46.20
# Epoch   200, train loss 0.004770, train error 0.00,  test loss 2.105117, test error 46.05
# Epoch   300, train loss 0.002709, train error 0.00,  test loss 2.227860, test error 45.85
# Epoch   400, train loss 0.001846, train error 0.00,  test loss 2.313644, test error 45.90
# Epoch   500, train loss 0.001382, train error 0.00,  test loss 2.379311, test error 46.17
# Epoch   600, train loss 0.001096, train error 0.00,  test loss 2.431638, test error 46.15
# Epoch   700, train loss 0.000902, train error 0.00,  test loss 2.475387, test error 46.20
# Epoch   800, train loss 0.000764, train error 0.00,  test loss 2.513574, test error 46.25
# Epoch   900, train loss 0.000660, train error 0.00,  test loss 2.546583, test error 46.25
# Training model with 400 hidden variables
# Epoch     0, train loss 1.860378, train error 65.28,  test loss 1.777224, test error 68.12
# Epoch   100, train loss 0.011765, train error 0.00,  test loss 1.782817, test error 45.78
# Epoch   200, train loss 0.004182, train error 0.00,  test loss 1.964664, test error 45.70
# Epoch   300, train loss 0.002419, train error 0.00,  test loss 2.067125, test error 45.72
# Epoch   400, train loss 0.001667, train error 0.00,  test loss 2.137168, test error 45.65
# Epoch   500, train loss 0.001256, train error 0.00,  test loss 2.190915, test error 45.80
# Epoch   600, train loss 0.001000, train error 0.00,  test loss 2.234992, test error 45.80
# Epoch   700, train loss 0.000826, train error 0.00,  test loss 2.271574, test error 45.70
# Epoch   800, train loss 0.000701, train error 0.00,  test loss 2.303318, test error 45.72
# Epoch   900, train loss 0.000607, train error 0.00,  test loss 2.331144, test error 45.65

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all,'r-',label='train')
ax.plot(hidden_variables, errors_test_all,'b-',label='test')
ax.set_ylim(0,100);
ax.set_xlabel('No hidden variables'); ax.set_ylabel('Error')
ax.legend()
plt.show()
